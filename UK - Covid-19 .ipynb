# %%
import pandas as pd
from pandas import Series,DataFrame
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (14,6)
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
from pandas_datareader import data
from datetime import datetime

# %%
cv19_df = pd.read_csv("Covid Data.csv")

# %%
cv19_df[::-1]
# Out:
#           Date  Cum Cases  Hospital Cases  New Cases  Deaths  New 2nd Dose
# 574  31-Jan-20          2             NaN          2     NaN           NaN
# 573   1-Feb-20          2             NaN          0     NaN           NaN
# 572   2-Feb-20          2             NaN          0     NaN           NaN
# 571   3-Feb-20          2             NaN          0     NaN           NaN
# 570   4-Feb-20          2             NaN          0     NaN           NaN
# ..         ...        ...             ...        ...     ...           ...
# 4    23-Aug-21    6524581          6973.0      31914    40.0      131283.0
# 3    24-Aug-21    6555200          6908.0      30838   174.0      130676.0
# 2    25-Aug-21    6590747          6920.0      35847   149.0      161705.0
# 1    26-Aug-21    6628709          6942.0      38281   140.0      144936.0
# 0    27-Aug-21    6666399             NaN      38046   100.0           NaN
#
# [575 rows x 6 columns]

# %%
cv19_df
# Out:
#           Date  Cum Cases  Hospital Cases  New Cases  Deaths  New 2nd Dose
# 0    27-Aug-21    6666399             NaN      38046   100.0           NaN
# 1    26-Aug-21    6628709          6942.0      38281   140.0      144936.0
# 2    25-Aug-21    6590747          6920.0      35847   149.0      161705.0
# 3    24-Aug-21    6555200          6908.0      30838   174.0      130676.0
# 4    23-Aug-21    6524581          6973.0      31914    40.0      131283.0
# ..         ...        ...             ...        ...     ...           ...
# 570   4-Feb-20          2             NaN          0     NaN           NaN
# 571   3-Feb-20          2             NaN          0     NaN           NaN
# 572   2-Feb-20          2             NaN          0     NaN           NaN
# 573   1-Feb-20          2             NaN          0     NaN           NaN
# 574  31-Jan-20          2             NaN          2     NaN           NaN
#
# [575 rows x 6 columns]

# %%
# change the direction of the x axis with .invert_xaxis() method
cv19_df['New Cases'].plot(legend=True,figsize=(14,6)).invert_xaxis()

# %%
cv19_df[['New Cases','Hospital Cases','Deaths']].plot(legend=True,figsize=(14,6)).invert_xaxis()

# %%
cv19_df[['New 2nd Dose', 'Deaths']].plot(legend=True,figsize=(14,6)).invert_xaxis()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21120/571930330.py in <module>
# ----> 1 cv19_df[['New 2nd Dose', 'Deaths']].plot(legend=True,figsize=(14,6)).invert_xaxis()
#
# NameError: name 'cv19_df' is not defined
